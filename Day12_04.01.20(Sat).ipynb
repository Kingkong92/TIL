# %%
import requests
from bs4 import BeautifulSoup
import re

url = "https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105"
response=requests.get(url)
soup=BeautifulSoup(response.text,"html.parser")
main=soup.select("#main_content > div")
links=[]

main
# Out:
# [<div class="list_body section_index">
#  <div class="cluster">
#  <div class="cluster_title">
#  <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a><i class="cluster_title_icon_beta">beta</i></span>
#  <div class="cluster_title_layer _news_cluster_layer is_hidden">
#  <div class="cluster_title_layer_text">
#                              헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                          </div>
#  <div class="cluster_title_layer_image"></div>
#  <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
#  </div>
#  </div>
#  </div>
#  <div class="_persist">
#  <div class="cluster">
#  <div class="cluster_group _cluster_content" data-prior="57138652">
#  <div class="cluster_head">
#  <div class="cluster_head_inner">
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
from konlpy.tag import Okt 
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
twitter = Okt() 
morphs = [] 

url = "https://news.naver.com/main/read.nhn?mode=LS2D&mid=sec&sid1=103&sid2=248&oid=052&aid=0001384408" 
response=requests.get(url)
soup=BeautifulSoup(response.text,"html.parser")
myList=soup.select("#articleBodyContents")
myList_list=[]

for myLists in myList:
    myList_list.append(myLists)

sentences_tag = []
#형태소 분석하여 리스트에 넣기
for sentence in myList_list:
    morph = twitter.pos(sentence)
    sentences_tag.append(morph)
    print(morph)
    print('-' * 30)

print(sentences_tag)
print('\n' * 3)

noun_adj_list = []
#명사와 형용사만 구분하여 이스트에 넣기
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun', 'Adjective']:
            noun_adj_list.append(word)

#형태소별 count
counts = Counter(noun_adj_list)
tags = counts.most_common(word_count)
print(tags)

#wordCloud생성
#한글꺠지는 문제 해결하기위해 font_path 지정
wc = WordCloud(font_path='/Library/Fonts/NanumSquareLight.ttf', background_color='white', width=800, height=600)
print(dict(tags))
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# for sentence in t: 
#     morphs.append(twitter.pos(sentence)) 
    
#     print(morphs)



    
# # re.sub("[^가-힣\s]*",'',text)
# # #print(text)
# s =re.sub('[-=.#/?:$}]', '',a)
# # # print(clear_text)
# print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-feac362f52f4> in <module>
#      21 #형태소 분석하여 리스트에 넣기
#      22 for sentence in myList_list:
# ---> 23     morph = twitter.pos(sentence)
#      24     sentences_tag.append(morph)
#      25     print(morph)
#
# ~\Anaconda3\lib\site-packages\konlpy\tag\_okt.py in pos(self, phrase, norm, stem, join)
#      61                     phrase,
#      62                     jpype.java.lang.Boolean(norm),
# ---> 63                     jpype.java.lang.Boolean(stem)).toArray()
#      64         if join:
#      65             return [t for t in tokens]
#
# TypeError: No matching overloads found for kr.lucypark.okt.OktInterface.tokenize(Tag,java.lang.Boolean,java.lang.Boolean), options are:
# 	public java.util.List kr.lucypark.okt.OktInterface.tokenize(java.lang.String,java.lang.Boolean,java.lang.Boolean)
#
# ...

# %%
import konlpy
