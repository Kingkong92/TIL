# %%
미니 프로젝트

연락처 프로그램

1.Class 클래스 사용 -> 객체(개인)
기능적인 측면 클래스에 들어가는걸로 연습

메뉴 선택하는 거=> 커피 머신 선택하던것과비슷

2. 연락처 입력: 형식에 맞게 
    정규식을 연습.
    전화번호, 010-0000-0000 / 2자리든 3자리든, 
    이메일도 @ 예전에 공부했던거 참고해서 연습
=> contact.txt.csv 파일 저장하기

3. 연락처 삭제
    전화번호 검색. 1234(0000-0000) => 리스트(정보들 나와야한다)
    삭제할때 이름 유도 하거나,
    여러개 나오면 그중에서 선택해서 삭제할 수 있게.
    1234-5678, 5678-1234 // 0123-4567(X)

# %%
#Park 풀이방법. 주소록 입력 출력 삭제 종료
import re
from pandas import DataFrame
import pandas as pd


class Contact:

    def __init__(self,name, mobile, email, address): #생성자(초기화 메서드)
        self.name = name
        self.mobile = mobile
        self.email= email
        self.address=address
        return 
    
    def info(self):
        print("Name: ", self.name)
        print("Mobile: " , self.mobile)
        print("Email:", self.email)
        print("Address: ",self.address)
    
def insert():
    name=input("Name: ")
    if name == re.search('':
       print("Write more than 2 Characters less than 4 characters")
    
    mobile=input("Moblie: ")
    if mobile 
                         
    email=input("Email: ")
    address=input("address: ")
    contact=Contact(name, mobile, email, address)
    print("="*15,"Completed register","="*15 )
    return contact
    
def print_list(contact_list):
    for contact in contact_list:
        contact.info()
    print("="*15,"Completed printed list","="*15 )    
        
def delete(contact_list,name):    
    for i, contact in enumerate(contact_list):
        if contact.name == name:
            del contact_list[i]
        
    print("="*15,"Completed removed list","="*15 )
    


def save_list():
    contact=
    re.findall("")
    pd.to_csv("contact_txt.csv")

    
def menu_list():
    print("1. Insert contact")
    print("2. Printed list contact")
    print("3. Delete contact")
    print("4. Close")
    menu=int(input("Select number: "))
    return menu
    
def run():
    contact_list=[]
    
    while True:
        menu=menu_list()
        
        if menu == 1:
            contact= insert()
            contact_list.append(contact)
        
        elif menu == 2:
            print_list(contact_list)
            
        elif menu == 3:
            name = input("Name: ")
            delete(contact_list, name)
        
        elif menu == 4:
            break
        
        
                 
if __name__== "__main__":
    run()
# Out:
# 1. Insert contact
# 2. Printed list contact
# 3. Delete contact
# 4. Close
# Select number: 4

# %%
pat=re.compile("[0-9]{2,3}[-][0-9]{4}[-][0-9]{4}")
mobile
email=re.comile("(\w*[.,!?_$%]*)@(\w*[.])")

# %%
class contact: 
    def __init__(self, name,tel, email, addr):
        self.name=name
        ...
        
        
    def info(self):
        print("이름", self.name)
        ...
        

def run():
    hong=Contact("홍길동","010-1111-1111","test@test.com)
    hong.info()
                 
                 
                 
                 
                 
                 
if __name__='__main__':
        run()

# %%
print("="*15,"Completed register","="*15 )
# Out:
# =============== Completed register ===============

# %%
 # 연락처 입력(추가)        
    def add(self):        
        # csv파일 읽어오기
        data = pd.read_csv("Phone Book")
        
        Name = input("Name: ")
        Phone = input("Phone Number: ")
        Email = input("E-mail: ")
        Address = input("Address: ")
        
        # 정규식으로 입력값이 맞는 형태인지 확인
        n = re.match('[가-힣]{2,4}',Name)
        p = re.match('\d{3}[-]\d{4}[-]\d{4}|\d{2}[-]\d{3}[-]\d{4}',Phone)
        e = re.match('[0-9a-zA-Z][_0-9a-z.A-Z-]*@[_0-9a-zA-Z-]+(\.[_0-9a-zA-Z-]+){1,2}$',Email)
        a = re.match('[\w가-힣-\s]+',Address)
        
        
        if n and p and e and a:
            # 입력값을 DataFrame으로 생성 후 기존 데이터에 추가
            new = pd.DataFrame([[Name,Phone,Email,Address]],columns=['Name','Phone Number','E-mail','Address'])
            data = pd.concat([data,new],axis=0,ignore_index=True)
        else:
            print('잘못 입력된 정보가 있습니다. 다시 입력해주세요')
        
        # csv파일로 저장
        data.to_csv("Phone Book")
            
        return PhoneBook.main(self)

# %%
 # 연락처 추가
    def c_add(self) :
        import pandas as pd
        import re
        
        # 이름 입력
        name = input("\nName : ")
        
        # 전화번호 입력, 제대로 입력할 때까지 반복
        phone = input("Phone Number : ")
        phone_p = re.compile("[0-9]{2,3}-[0-9]{3,4}-[0-9]{4}")
        
        while not phone_p.match(phone) :
            print("전화번호 형식에 맞지 않습니다. 다시입력해 주세요.")
            phone = input("Phone Number : ")
        
        # 이메일 입력, 제대로 입력할 때까지 반복
        email = input("E-mail : ")
        email_p = re.compile("[a-zA-Z0-9+-._]+[@][a-zA-Z0-9-]+[.][a-zA-Z0-9.]+")
        
        while not email_p.match(email) :
            print("E-mail 형식에 맞지 않습니다. 다시입력해 주세요.")
            email = input("E-mail : ")
        
        # 주소 입력
        addr = input("Address : ")
        print("\n")
        
        # 완성된 연락처를 contact_df안에 저장
        # 첫 연락처의 경우 첫번째 줄에 저장
        if pd.isnull(self.contact_df.iloc[0, 0]) :
            self.contact_df.iloc[0,] = [name, phone, email, addr]
        
        # 처음이 아닌 경우 마지막줄 위치 찾아서 저장
        else :
            # 몇번째 연락처인지 확인
            num = len(self.contact_df)
            self.contact_df.loc[num] = [name, phone, email, addr]
        
        # 메뉴로 돌아가기
        self.menu_choice()

# %%
연락처 만들기

class contact :
    def __init__(self) :
        import pandas as pd
        
        # 연락처 저장을 위한 자료 불러오거나 생성하기
        try : 
            self.contact_df = pd.read_csv('contact.csv')
            if len(self.contact_df) == 0 :
                self.contact_df = pd.DataFrame(index = range(0,1), columns=["Name", "PhoneNumber", "E-mail", "Address"])
        except FileNotFoundError : 
            self.contact_df = pd.DataFrame(index = range(0,1), columns=["Name", "PhoneNumber", "E-mail", "Address"])
                    
        self.menu_choice()    
    
    #--------------------------------------------------------
    # 수행할 메뉴 선택하기
    def menu_choice(self) :
        print("1. 연락처 입력")
        print("2. 연락처 출력")
        print("3. 연락처 삭제")
        print("4. 연락처 검색")
        print("5. 종료")
        self.menu = input("메뉴선택 : ")
        
        # 선택된 메뉴에 따라 이동
        if self.menu == "1" : self.c_add()
        elif self.menu == "2" : self.c_print()
        elif self.menu == "3" : self.c_remove()
        elif self.menu == "4" : self.c_search()
        elif self.menu == "5" : self.c_quit()
        else : 
            # 잘못된 값을 입력한 경우, 문구 출력 후 돌아가기
            print("\n잘못입력하셨습니다. 다시 입력해주세요")
            self.menu_choice()
            
    
    #--------------------------------------------------------
    # 연락처 추가
    def c_add(self) :
        import pandas as pd
        import re
        
        # 이름 입력
        name = input("\nName : ")
        
        # 전화번호 입력, 제대로 입력할 때까지 반복
        phone = input("Phone Number : ")
        phone_p = re.compile("[0-9]{2,3}-[0-9]{3,4}-[0-9]{4}")
        
        while not phone_p.match(phone) :
            print("전화번호 형식에 맞지 않습니다. 다시입력해 주세요.")
            phone = input("Phone Number : ")
        
        # 이메일 입력, 제대로 입력할 때까지 반복
        email = input("E-mail : ")
        email_p = re.compile("[a-zA-Z0-9+-._]+[@][a-zA-Z0-9-]+[.][a-zA-Z0-9.]+")
        
        while not email_p.match(email) :
            print("E-mail 형식에 맞지 않습니다. 다시입력해 주세요.")
            email = input("E-mail : ")
        
        # 주소 입력
        addr = input("Address : ")
        print("\n")
        
        # 완성된 연락처를 contact_df안에 저장
        # 첫 연락처의 경우 첫번째 줄에 저장
        if pd.isnull(self.contact_df.iloc[0, 0]) :
            self.contact_df.iloc[0,] = [name, phone, email, addr]
        
        # 처음이 아닌 경우 마지막줄 위치 찾아서 저장
        else :
            # 몇번째 연락처인지 확인
            num = len(self.contact_df)
            self.contact_df.loc[num] = [name, phone, email, addr]
        
        # 메뉴로 돌아가기
        self.menu_choice()
    
    #--------------------------------------------------------
    # 연락처 출력
    def c_print(self) :
        import pandas as pd
        
        # 저장된 연락처가 없는 경우, 문구 출력 후 메뉴로 돌아가기
        if pd.isnull(self.contact_df.iloc[0, 0]) : 
            print("\n저장된 연락처가 없습니다.\n")
            self.menu_choice()
        
        # 저장된 연락처들 출력 후, 메뉴로 돌아가기 
        else : 
            print("\n", "-"*39)
            print(self.contact_df)
            print("-"*40, "\n")
            self.menu_choice()
    
    #--------------------------------------------------------
    # 연락처 삭제
    def c_remove(self) :
        import pandas as pd
        
        # 저장된 연락처가 없는 경우, 문구 출력 후 메뉴로 돌아가기
        if pd.isnull(self.contact_df.iloc[0, 0]) : 
            print("\n삭제할 수 있는 연락처가 없습니다.\n")
            self.menu_choice()
            
        # 먼저 저장된 연락처 출력
        else : 
            print("\n", "-"*39)
            print(self.contact_df)
            print("-"*40, "\n")
            
            # 삭제할 연락처 입력받기
            print("\n삭제하고 싶으신 연락처의 인덱스 번호를 입력해주세요.")
            print("삭제하고 싶지 않으시면 'c'를 입력해주세요.")
            remove_num = input()
            print("\n")

            # 'c'를 입력한 경우, 메뉴로 돌아가기
            if remove_num == 'c' :
                self.menu_choice()

            # 연락처 범위 안에 숫자를 입력하면 연락처 삭제
            elif remove_num.isdigit() :
                if int(remove_num) < len(self.contact_df) :
                    # 연락처 삭제, 행 인덱스 재설정
                    self.contact_df = self.contact_df.drop(int(remove_num), 0).reset_index(drop=True)
                    self.menu_choice()
                
                # 잘못된 값을 입력할 경우, 연락처 삭제 처음으로 돌아가기
                else : 
                    print("\n잘못된 값을 입력하셨습니다.")
                    self.c_remove()
            
            else : 
                print("\n잘못된 값을 입력하셨습니다.")
                self.c_remove()
             
    #--------------------------------------------------------
    # 연락처 검색
    def c_search(self) :
        import re
        
        # 검색어 입력
        verb = input("\n검색어 : ")
        
        # 검색어에 해당되는 인덱스 저장 리스트
        s_list = list()
        
        p = re.compile(verb)
        
        # 검색어에 해당하는 연락처가 있는지 찾기
        for i in range(len(self.contact_df)) :
            if p.search(self.contact_df.iloc[i, 0]) :
                s_list.append(i)
            elif p.search(self.contact_df.iloc[i, 1]) :
                s_list.append(i)
            elif p.search(self.contact_df.iloc[i, 2]) :
                s_list.append(i)
            elif p.search(self.contact_df.iloc[i, 3]) :
                s_list.append(i)
        
        # 해당하는 연락처가 없는 경우, 문구 출력 후 메뉴로 돌아가기
        if len(s_list) == 0 :
            print("검색어에 해당하는 연락처가 없습니다.\n")
            self.menu_choice()
        
        # 해당하는 연락처가 있는 경우, 해당 연락처 출력하고 메뉴로 돌아가기
        else :
            print("-"*40)
            print(self.contact_df.iloc[s_list,])
            print("-"*40, "\n")
            self.menu_choice()
    
    #--------------------------------------------------------
    # 프로그램 끄기
    def c_quit(self) : 
        # 연락처 저장
        self.contact_df.to_csv("contact.csv", index=False)
        return

# %%
# 함수안에서 자기자신의 함수를 호출하면 함수를 호출한곳으로 되돌아가면
# 메모리에 똑같은 변수들이 계속 쌓인다. 
# 메모리의 객체는 힙에 저장되는다. 
# 메모리의 stack 영역에 일시적인 지역변수들이 저장되어지는 공간. 차곡 차곡 쌓여간다.
# 함수의 return 때문에

# %%
#최종 주소록 
from pandas import DataFrame
import pandas as pd
import re

class Contact:
    def __init__(self, name, mobile, email, address)
    self.name=name
    self.mobile=mobile
    self.email=email
    self.address=address
    data.to_csv("contact_text.csv")
